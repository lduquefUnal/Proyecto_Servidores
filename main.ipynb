# %% [markdown]
# # SISTEMA DE PROCESAMIENTO DE IMÁGENES CON ML
# ## Descripción
# Desarrollar una aplicación que permita a usuarios subir imágenes, las procese
# automáticamente con ML (reconocimiento de objetos, moderación de contenido, extracción
# de texto) y almacene metadatos.
# Arquitectura AWS
# ![image.png](image.png)
